# %%
import pandas as pd

# %%
df = pd.read_csv('standard-element-concentrations.csv')

# %%
df
# Out:
#                mineral       Si       Ti      Al      Fe       Mg  \
# 0               quartz  46.7400      NaN     NaN     NaN      NaN
# 1               sphene  14.3300  24.4300     NaN     NaN      NaN
# 2            anorthite  20.6100   0.0060  18.770   0.360   0.0500
# 3             diopside  25.9420   0.0180   0.021   0.086  11.2160
# 4              MgAl2O4      NaN      NaN  37.930     NaN  17.0900
# 5                Al2O3      NaN      NaN  52.930     NaN      NaN
# 6               albite  32.1300      NaN  10.250   0.050      NaN
# 7               augite  23.6000   0.3100   3.990   3.650  10.4400
# 8            enstatite  27.9700      NaN     NaN     NaN  24.2200
# 9             ilmenite      NaN  27.4000     NaN  36.168   0.1869
# 10               Scolv  19.0800      NaN     NaN   7.420  29.8000
# 11                TiO2      NaN  59.9500     NaN     NaN      NaN
# 12        wollastonite  24.1772      NaN     NaN     NaN      NaN
# ...
